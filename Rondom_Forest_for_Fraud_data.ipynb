# %% [markdown]
# <a href="https://colab.research.google.com/github/damerasaikumar1234/Data--Science--Assignments/blob/main/Rondom_Forest_for_Fraud_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Use Random Forest to prepare a model on fraud data treating those who have taxable_income <= 30000 as "Risky" and others are "Good"

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("Fraud_check (1).csv")
df
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# 595                7   YES
# 596                2   YES
# 597                0   YES
# 598               17    NO
# 599               16    NO
#
# [600 rows x 6 columns]

# %%
list(df)
# Out:
# ['Undergrad',
#  'Marital.Status',
#  'Taxable.Income',
#  'City.Population',
#  'Work.Experience',
#  'Urban']

# %%
df["Taxable.Income"]=["Good" if value > 30000
                      else "Risky" for value in df['Taxable.Income']]

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

Columns_to_encoder=["Undergrad","Marital.Status","Urban","Taxable.Income"]
for columns in Columns_to_encoder:
 df[columns]=LE.fit_transform(df[columns])
df
# Out:
#      Undergrad  Marital.Status  Taxable.Income  City.Population  \
# 0            0               2               0            50047
# 1            1               0               0           134075
# 2            0               1               0           160205
# 3            1               2               0           193264
# 4            0               1               0            27533
# ..         ...             ...             ...              ...
# 595          1               0               0            39492
# 596          1               0               0            55369
# 597          0               0               0           154058
# 598          1               1               0           180083
# 599          0               0               0           158137
#
#      Work.Experience  Urban
# 0                 10      1
# 1                 18      1
# 2                 30      1
# 3                 15      1
# 4                 28      0
# ..               ...    ...
# 595                7      1
# 596                2      1
# 597                0      1
# 598               17      0
# 599               16      0
#
# [600 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Undergrad          0
# Marital.Status     0
# Taxable.Income     0
# City.Population    0
# Work.Experience    0
# Urban              0
# dtype: int64

# %%
X=df[["Undergrad","Marital.Status","City.Population","Work.Experience","Urban"]]
Y=df["Taxable.Income"]

# %%
df.corr()
# Out:
#                  Undergrad  Marital.Status  Taxable.Income  City.Population  \
# Undergrad         1.000000        0.042407        0.012523         0.079579
# Marital.Status    0.042407        1.000000        0.006081        -0.001564
# Taxable.Income    0.012523        0.006081        1.000000         0.012225
# City.Population   0.079579       -0.001564        0.012225         1.000000
# Work.Experience  -0.005362       -0.002213       -0.001972         0.013135
# Urban            -0.000267        0.064562        0.004830        -0.040098
#
#                  Work.Experience     Urban
# Undergrad              -0.005362 -0.000267
# Marital.Status         -0.002213  0.064562
# Taxable.Income         -0.001972  0.004830
# City.Population         0.013135 -0.040098
# Work.Experience         1.000000 -0.094559
# Urban                  -0.094559  1.000000

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y)

# %%
from sklearn.tree import DecisionTreeClassifier
DTC=DecisionTreeClassifier()
DTC.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
Y_pred_train=DTC.predict(X_train)
Y_pred_test=DTC.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
ac1=accuracy_score(Y_train,Y_pred_train)
ac2=accuracy_score(Y_test,Y_pred_test)
print("Accuracy Score for Training Data:",ac1.round(3))
print("Accuracy Score for Test Data:",ac2.round(3))
# Out:
# Accuracy Score for Training Data: 1.0
# Accuracy Score for Test Data: 0.713

# %%
from sklearn.ensemble import RandomForestClassifier
RFC=RandomForestClassifier(n_estimators=100,
                           max_samples=0.6,
                           max_features=0.7)
RFC.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(max_features=0.7, max_samples=0.6)

# %%
Y_pred_train=RFC.predict(X_train)
Y_pred_test=RFC.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
ac1=accuracy_score(Y_train,Y_pred_train)
ac2=accuracy_score(Y_test,Y_pred_test)
print("Accuracy Score for Training Data:",ac1.round(3))
print("Accuracy Score fro Test Data:",ac2.round(3))
# Out:
# Accuracy Score for Training Data: 0.944
# Accuracy Score fro Test Data: 0.807

# %%
from sklearn import tree
tree.plot_tree(DTC)
# Out:
# [Text(0.7993088942307692, 0.975, 'x[2] <= 197770.0\ngini = 0.343\nsamples = 450\nvalue = [351, 99]'),
#  Text(0.6140024038461539, 0.925, 'x[2] <= 140941.5\ngini = 0.338\nsamples = 445\nvalue = [349, 96]'),
#  Text(0.3222355769230769, 0.875, 'x[2] <= 140702.0\ngini = 0.365\nsamples = 320\nvalue = [243, 77]'),
#  Text(0.31454326923076925, 0.825, 'x[2] <= 80947.5\ngini = 0.36\nsamples = 318\nvalue = [243, 75]'),
#  Text(0.12451923076923077, 0.775, 'x[2] <= 37925.0\ngini = 0.295\nsamples = 156\nvalue = [128, 28]'),
#  Text(0.05, 0.725, 'x[2] <= 33045.5\ngini = 0.408\nsamples = 35\nvalue = [25, 10]'),
#  Text(0.015384615384615385, 0.675, 'x[0] <= 0.5\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(0.007692307692307693, 0.625, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.023076923076923078, 0.625, 'x[2] <= 28476.0\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.015384615384615385, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03076923076923077, 0.575, 'x[1] <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.015384615384615385, 0.525, 'x[2] <= 28937.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.007692307692307693, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.023076923076923078, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.046153846153846156, 0.525, 'x[3] <= 17.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.038461538461538464, 0.475, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.05384615384615385, 0.475, 'x[2] <= 31509.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.046153846153846156, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06153846153846154, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08461538461538462, 0.675, 'x[1] <= 0.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.07692307692307693, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.09230769230769231, 0.625, 'x[2] <= 36940.0\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.08461538461538462, 0.575, 'x[4] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.07692307692307693, 0.525, 'x[3] <= 13.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.06923076923076923, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08461538461538462, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09230769230769231, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19903846153846153, 0.725, 'x[2] <= 60294.5\ngini = 0.253\nsamples = 121\nvalue = [103, 18]'),
#  Text(0.1346153846153846, 0.675, 'x[3] <= 6.5\ngini = 0.168\nsamples = 65\nvalue = [59, 6]'),
#  Text(0.12692307692307692, 0.625, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.1423076923076923, 0.625, 'x[3] <= 8.5\ngini = 0.198\nsamples = 54\nvalue = [48, 6]'),
#  Text(0.11538461538461539, 0.575, 'x[2] <= 44224.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.1076923076923077, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12307692307692308, 0.525, 'x[2] <= 54987.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11538461538461539, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13076923076923078, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16923076923076924, 0.575, 'x[2] <= 58233.0\ngini = 0.147\nsamples = 50\nvalue = [46, 4]'),
#  Text(0.15384615384615385, 0.525, 'x[0] <= 0.5\ngini = 0.12\nsamples = 47\nvalue = [44, 3]'),
#  Text(0.14615384615384616, 0.475, 'x[2] <= 39441.5\ngini = 0.198\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.13076923076923078, 0.425, 'x[1] <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.12307692307692308, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13846153846153847, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16153846153846155, 0.425, 'x[3] <= 21.0\ngini = 0.147\nsamples = 25\nvalue = [23, 2]'),
#  Text(0.15384615384615385, 0.375, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.16923076923076924, 0.375, 'x[1] <= 1.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.16153846153846155, 0.325, 'x[3] <= 24.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.15384615384615385, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16923076923076924, 0.275, 'x[4] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.16153846153846155, 0.225, 'x[2] <= 44828.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.15384615384615385, 0.175, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16923076923076924, 0.175, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17692307692307693, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.17692307692307693, 0.325, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.16153846153846155, 0.475, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.18461538461538463, 0.525, 'x[3] <= 22.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.17692307692307693, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.19230769230769232, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.26346153846153847, 0.675, 'x[3] <= 13.5\ngini = 0.337\nsamples = 56\nvalue = [44, 12]'),
#  Text(0.23076923076923078, 0.625, 'x[3] <= 2.5\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(0.2230769230769231, 0.575, 'x[2] <= 76515.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.2153846153846154, 0.525, 'x[4] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2076923076923077, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2230769230769231, 0.475, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.23076923076923078, 0.525, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.23846153846153847, 0.575, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.29615384615384616, 0.625, 'x[3] <= 19.5\ngini = 0.43\nsamples = 32\nvalue = [22, 10]'),
#  Text(0.26153846153846155, 0.575, 'x[2] <= 74803.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.24615384615384617, 0.525, 'x[2] <= 63322.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.23846153846153847, 0.475, 'x[2] <= 61971.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.23076923076923078, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.24615384615384617, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.25384615384615383, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.27692307692307694, 0.525, 'x[3] <= 16.5\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.2692307692307692, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2846153846153846, 0.475, 'x[0] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.27692307692307694, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2923076923076923, 0.425, 'x[1] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2846153846153846, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.33076923076923076, 0.575, 'x[2] <= 78701.0\ngini = 0.32\nsamples = 20\nvalue = [16, 4]'),
#  Text(0.3230769230769231, 0.525, 'x[2] <= 67197.5\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.3153846153846154, 0.475, 'x[4] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.3076923076923077, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3230769230769231, 0.425, 'x[3] <= 26.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.3153846153846154, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.33076923076923076, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.33076923076923076, 0.475, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.3384615384615385, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5045673076923077, 0.775, 'x[2] <= 82976.5\ngini = 0.412\nsamples = 162\nvalue = [115, 47]'),
#  Text(0.496875, 0.725, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5122596153846154, 0.725, 'x[1] <= 0.5\ngini = 0.392\nsamples = 157\nvalue = [115, 42]'),
#  Text(0.375, 0.675, 'x[2] <= 88268.0\ngini = 0.298\nsamples = 55\nvalue = [45, 10]'),
#  Text(0.36730769230769234, 0.625, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.38269230769230766, 0.625, 'x[2] <= 91893.5\ngini = 0.32\nsamples = 50\nvalue = [40, 10]'),
#  Text(0.36153846153846153, 0.575, 'x[4] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.35384615384615387, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36923076923076925, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.40384615384615385, 0.575, 'x[2] <= 108004.5\ngini = 0.282\nsamples = 47\nvalue = [39, 8]'),
#  Text(0.38461538461538464, 0.525, 'x[2] <= 96542.0\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.3769230769230769, 0.475, 'x[3] <= 12.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.36923076923076925, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.38461538461538464, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3923076923076923, 0.475, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.4230769230769231, 0.525, 'x[2] <= 108253.5\ngini = 0.327\nsamples = 34\nvalue = [27, 7]'),
#  Text(0.4153846153846154, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4307692307692308, 0.475, 'x[3] <= 19.5\ngini = 0.298\nsamples = 33\nvalue = [27, 6]'),
#  Text(0.4, 0.425, 'x[2] <= 124245.0\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.3923076923076923, 0.375, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.4076923076923077, 0.375, 'x[2] <= 126791.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.4, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4153846153846154, 0.325, 'x[3] <= 11.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.4076923076923077, 0.275, 'x[2] <= 135945.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4153846153846154, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4230769230769231, 0.275, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.46153846153846156, 0.425, 'x[2] <= 118348.5\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.43846153846153846, 0.375, 'x[3] <= 24.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.4307692307692308, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4461538461538462, 0.325, 'x[2] <= 112954.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.43846153846153846, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.45384615384615384, 0.275, 'x[3] <= 29.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4461538461538462, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.46153846153846156, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4846153846153846, 0.375, 'x[3] <= 21.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.47692307692307695, 0.325, 'x[2] <= 122911.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.46923076923076923, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4846153846153846, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.49230769230769234, 0.325, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.6495192307692308, 0.675, 'x[2] <= 126754.5\ngini = 0.431\nsamples = 102\nvalue = [70, 32]'),
#  Text(0.6067307692307692, 0.625, 'x[2] <= 117755.5\ngini = 0.387\nsamples = 80\nvalue = [59, 21]'),
#  Text(0.5673076923076923, 0.575, 'x[2] <= 100673.5\ngini = 0.43\nsamples = 64\nvalue = [44, 20]'),
#  Text(0.5346153846153846, 0.525, 'x[3] <= 15.5\ngini = 0.305\nsamples = 32\nvalue = [26, 6]'),
#  Text(0.5153846153846153, 0.475, 'x[0] <= 0.5\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.5076923076923077, 0.425, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.5230769230769231, 0.425, 'x[3] <= 5.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.5153846153846153, 0.375, 'x[3] <= 2.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5076923076923077, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5230769230769231, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5307692307692308, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.5538461538461539, 0.475, 'x[3] <= 17.0\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.5461538461538461, 0.425, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5615384615384615, 0.425, 'x[2] <= 88155.0\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(0.5461538461538461, 0.375, 'x[3] <= 28.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5384615384615384, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5538461538461539, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5769230769230769, 0.375, 'x[2] <= 94323.0\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.5692307692307692, 0.325, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.5846153846153846, 0.325, 'x[2] <= 95887.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.5769230769230769, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5923076923076923, 0.275, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6, 0.525, 'x[2] <= 102112.0\ngini = 0.492\nsamples = 32\nvalue = [18, 14]'),
#  Text(0.5846153846153846, 0.475, 'x[3] <= 18.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.5769230769230769, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.5923076923076923, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6153846153846154, 0.475, 'x[2] <= 102862.0\ngini = 0.477\nsamples = 28\nvalue = [17, 11]'),
#  Text(0.6076923076923076, 0.425, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6230769230769231, 0.425, 'x[3] <= 5.5\ngini = 0.493\nsamples = 25\nvalue = [14, 11]'),
#  Text(0.6153846153846154, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6307692307692307, 0.375, 'x[3] <= 9.0\ngini = 0.5\nsamples = 22\nvalue = [11, 11]'),
#  Text(0.6230769230769231, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6384615384615384, 0.325, 'x[2] <= 104545.5\ngini = 0.495\nsamples = 20\nvalue = [11, 9]'),
#  Text(0.6230769230769231, 0.275, 'x[3] <= 29.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.6153846153846154, 0.225, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6307692307692307, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6538461538461539, 0.275, 'x[3] <= 22.5\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.6461538461538462, 0.225, 'x[2] <= 109709.0\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.6307692307692307, 0.175, 'x[2] <= 105527.0\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6230769230769231, 0.125, 'x[3] <= 16.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6153846153846154, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6307692307692307, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6384615384615384, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6615384615384615, 0.175, 'x[2] <= 112832.0\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.6538461538461539, 0.125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6692307692307692, 0.125, 'x[0] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.6615384615384615, 0.075, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.676923076923077, 0.075, 'x[2] <= 116705.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.6692307692307692, 0.025, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6846153846153846, 0.025, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6615384615384615, 0.225, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.6461538461538462, 0.575, 'x[3] <= 8.0\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.6384615384615384, 0.525, 'x[3] <= 4.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.6307692307692307, 0.475, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6461538461538462, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6538461538461539, 0.525, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.6923076923076923, 0.625, 'x[2] <= 130364.0\ngini = 0.5\nsamples = 22\nvalue = [11, 11]'),
#  Text(0.676923076923077, 0.575, 'x[3] <= 12.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.6692307692307692, 0.525, 'x[2] <= 128965.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6615384615384615, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.676923076923077, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6846153846153846, 0.525, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7076923076923077, 0.575, 'x[2] <= 132714.5\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.7, 0.525, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.7153846153846154, 0.525, 'x[2] <= 139144.5\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.7076923076923077, 0.475, 'x[3] <= 2.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.7, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7153846153846154, 0.425, 'x[0] <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.7076923076923077, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7230769230769231, 0.375, 'x[2] <= 138028.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.7153846153846154, 0.325, 'x[2] <= 133497.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.7076923076923077, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7230769230769231, 0.275, 'x[1] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.7153846153846154, 0.225, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7307692307692307, 0.225, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7307692307692307, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7230769230769231, 0.475, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.32992788461538464, 0.825, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9057692307692308, 0.875, 'x[3] <= 29.5\ngini = 0.258\nsamples = 125\nvalue = [106, 19]'),
#  Text(0.8576923076923076, 0.825, 'x[1] <= 1.5\ngini = 0.243\nsamples = 120\nvalue = [103, 17]'),
#  Text(0.7846153846153846, 0.775, 'x[3] <= 2.5\ngini = 0.284\nsamples = 76\nvalue = [63, 13]'),
#  Text(0.7538461538461538, 0.725, 'x[3] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.7461538461538462, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7615384615384615, 0.675, 'x[2] <= 190733.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7538461538461538, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7692307692307693, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8153846153846154, 0.725, 'x[2] <= 177179.5\ngini = 0.259\nsamples = 72\nvalue = [61, 11]'),
#  Text(0.7923076923076923, 0.675, 'x[2] <= 175998.5\ngini = 0.325\nsamples = 44\nvalue = [35, 9]'),
#  Text(0.7846153846153846, 0.625, 'x[2] <= 163299.5\ngini = 0.278\nsamples = 42\nvalue = [35, 7]'),
#  Text(0.7692307692307693, 0.575, 'x[2] <= 150481.5\ngini = 0.185\nsamples = 29\nvalue = [26, 3]'),
#  Text(0.7615384615384615, 0.525, 'x[2] <= 149074.0\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.7538461538461538, 0.475, 'x[4] <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.7461538461538462, 0.425, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.7615384615384615, 0.425, 'x[2] <= 147858.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.7538461538461538, 0.375, 'x[2] <= 146679.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.7461538461538462, 0.325, 'x[3] <= 12.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.7384615384615385, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7538461538461538, 0.275, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7615384615384615, 0.325, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7692307692307693, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7692307692307693, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7769230769230769, 0.525, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.8, 0.575, 'x[2] <= 164783.0\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.7923076923076923, 0.525, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8076923076923077, 0.525, 'x[2] <= 172851.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.8, 0.475, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.8153846153846154, 0.475, 'x[2] <= 173183.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.8076923076923077, 0.425, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.823076923076923, 0.425, 'x[2] <= 174091.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.8153846153846154, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8307692307692308, 0.375, 'x[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.823076923076923, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8384615384615385, 0.325, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.625, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8384615384615385, 0.675, 'x[4] <= 0.5\ngini = 0.133\nsamples = 28\nvalue = [26, 2]'),
#  Text(0.8307692307692308, 0.625, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.8461538461538461, 0.625, 'x[3] <= 21.5\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.8307692307692308, 0.575, 'x[2] <= 193154.0\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.823076923076923, 0.525, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.8384615384615385, 0.525, 'x[1] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8307692307692308, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8461538461538461, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8615384615384616, 0.575, 'x[2] <= 188909.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8538461538461538, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8692307692307693, 0.525, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9307692307692308, 0.775, 'x[2] <= 188046.0\ngini = 0.165\nsamples = 44\nvalue = [40, 4]'),
#  Text(0.9153846153846154, 0.725, 'x[2] <= 158413.5\ngini = 0.105\nsamples = 36\nvalue = [34, 2]'),
#  Text(0.9076923076923077, 0.675, 'x[2] <= 157673.0\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(0.9, 0.625, 'x[3] <= 12.5\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.8923076923076924, 0.575, 'x[3] <= 9.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.8846153846153846, 0.525, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9, 0.525, 'x[2] <= 155656.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8923076923076924, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9076923076923077, 0.475, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9076923076923077, 0.575, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.9153846153846154, 0.625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9230769230769231, 0.675, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.9461538461538461, 0.725, 'x[2] <= 192724.0\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.9384615384615385, 0.675, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9538461538461539, 0.675, 'x[3] <= 22.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.9461538461538461, 0.625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.9615384615384616, 0.625, 'x[0] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.9538461538461539, 0.575, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9692307692307692, 0.575, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9538461538461539, 0.825, 'x[1] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.9461538461538461, 0.775, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.9615384615384616, 0.775, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9846153846153847, 0.925, 'x[4] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.9769230769230769, 0.875, 'x[0] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.9692307692307692, 0.825, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9846153846153847, 0.825, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9923076923076923, 0.875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]')]

# %%
import sklearn.tree as tree
import graphviz
data=tree.export_graphviz(DTC,filled=True,rounded=True)
Graph=graphviz.Source(data)
Graph
